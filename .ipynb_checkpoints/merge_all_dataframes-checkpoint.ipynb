# %%
import pandas as pd

# %%
boys = pd.read_csv('data/colors_of_toys_category_boy.csv')
girls = pd.read_csv('data/colors_of_toys_category_girl.csv')

# %%
children = boys.append(girls)
children
# Out:
#   성별구분     카테고리명        카테고리ID  총 개수
# 0   남아      역할놀이  C10100030001   279
# 1   남아        액션  C10100030002   707
# 2   남아        조종  C10100030003   227
# 3   남아    자동차/기차  C10100030004   767
# 4   남아  프라모델/피규어  C10100030005   553
# 0   여아      역할놀이  C10100020001   436
# 1   여아        인형  C10100020002  2105
# 2   여아       꾸미기  C10100020003   394
# 3   여아    DIY/취미  C10100020004   466

# %%
categories = children['카테고리ID'].tolist()
categories
# Out:
# ['C10100030001',
#  'C10100030002',
#  'C10100030003',
#  'C10100030004',
#  'C10100030005',
#  'C10100020001',
#  'C10100020002',
#  'C10100020003',
#  'C10100020004']

# %%
pd.read_csv('data/C10100020001_0.csv')
# Out:
#                           제품명
# 0             나도 동영상 스타 미미노트북
# 1                똘똘이 아이스크림 가게
# 2                 멜리사앤더그 쇼핑카트
# 3            콩순이 알록달록 아이스크림가게
# 4              영실업 콩순이숫자놀이계산대
# 5            콩순이 동전을 하나둘셋 자판기
# 6               영실업 펭이와말하는청진기
# 7              코코밍 모여라 스페셜 세트
# 8                달님이 아이스크림 가게
# 9                 영실업 콩순이 편의점
# 10            영실업 콩순이말하는에듀청소기
# 11             영실업 콩순이 부푸러빵가게
# 12                 달님이 햄버거 가게
# 13              쥬쥬 메이크업헤어디자이너
# 14             영실업 콩순이119병원놀이
# 15                 치카치카 목욕똘똘이
# 16                   세라의 공주카페
# 17                   세라의 팝콘가게
# 18             콩순이 냄비가끓는짜장면가게
# 19             영실업 콩순이 가방동물병원
# 20                 뽀로로 말하는자판기
# 21                    코코밍 아로밍
# 22                    코코밍 베이밍
# 23                 쥬쥬 시크릿안전금고
# 24                 홈 펀 프렌즈 키친
# 25                    캐리 비밀금고
# 26                   똘똘이 청소놀이
# 27                  뽀로로 아기청소기
# 28                   목욕놀이 똘똘이
# 29                  코코밍 엔젤멜로밍
# ..                        ...
# 60         [멜리사앤더그] 아이스크림 만들기
# 61  [플랜토이즈] 주방놀이 도로 세트 660...
# 62   [플랜토이즈] 주방놀이 생선과 고기세트...
# 63     [플랜토이즈] 주방놀이 티 타임 3433
# 64  [플레이써클] 벨크로과일야채세트 / 플레...
# 65  [플레이써클] 아이스크림파티세트 / 플레...
# 66      [아메리칸플라스틱토이] 마이큐티주방놀이
# 67     [금성]헬로우 바니 장보기 소꿉-주방놀이
# 68          [금성]헬로우 바니 주방놀이세트
# 69  [들딸기]쇼콜라 파티 스위트 소꿉놀이 세...
# 70        [들딸기]스위트 카페 소꿉놀이 세트
# 71     [들딸기]쵸코렛 생일케이크 소꿉놀이 세트
# 72           [들딸기]토스터 소꿉놀이 세트
# 73  [노벨랜드]DIY우든 그린키친-소형 소꿉...
# 74                    소프트음식A형
# 75          [캐스B]플레이 파스텔과일자르기
# 76  [보쉬토이] 토스터 / 보쉬 주방놀이 역...
# 77               폴리 슈퍼마켓계산대놀이
# 78  [노벨랜드]GT- 스탠드 야채가게 소꿉놀...
# 79              토이즈킹_아이스크림 가게
# 80               아기똘똘이 스페셜 의상
# 81  [플레이써클] 진공청소기세트 / 플레이핑...
# 82        [WORLD]신나는 청소기 소꿉놀이
# 83            맥스터핀스 호스피탈 의사가방
# 84  [들딸기]NEW 클리닉 병원놀이 소꿉놀이...
# 85        [세스] 치과 의사 역할 놀이 세트
# 86  [캐스돈] CASDON 네비운전놀이 (C...
# 87        [멜리사앤더그] 발레리나 치마 세트
# 88      [멜리사앤더그] 역할놀이 모자 세트 B
# 89        (세주) 과일토끼 병원놀이/랜덤발송
#
# [90 rows x 1 columns]
